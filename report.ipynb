# %%
from main import load_or_create_the_index ,ORIGIN_DATA 
from query import Query

# %%
load_or_create_the_index()
# Out:
# loading index from file

# %%
def print_origin_new(res):
    print('\n\n'.join([ORIGIN_DATA[j]['title'] +" -- "+str(i+1) for i,j in enumerate(res)]))

# %%
ORIGIN_DATA[7043]['content']
# Out:
# 'به گزارش ایسنا، رحمان قفلگری از جمله شهیدان جهاد دانشگاهی در دوران دفاع مقدس\nمحسوب می\u200cشود. وی متولد ۱۳۴۳ در شهرستان اهر بود.قفلگری در برهه\u200cای از زمان\u200c، چشم\nبه جهان گشود که پیری فرزانه، علم مبارزه\u200c با طاغوت را برافراشته بود و خشم\nظالمانه کفر در همین ایام وی را(امام ره) از وطن اسلامی به دیار تبعید می\u200cفرستاد\nو بی\u200cشک این شهید از همان طفلان در گهواره\u200cای بود که امامش آینده را با بالندگی و\nقیام آنها روشن می\u200cدید.\n\nرحمان با ورود به مدرسه و محیط علم\u200c، دوران ابتدایی تا متوسطه را در شهرستان اهر\nگذرانده و خود را آماده ورود به مرحله جدیدی از دوران حساس زندگی علمی کرد.\n\nوقوع انقلاب شکوه\u200cمند اسلامی مصادف با حساس\u200cترین سال\u200cهای نوجوانی وی یعنی چهارده\nسالگی بود.\n\nعلاقه مذهبی نشات گرفته از خانواده و علاقه مفرط وی مبین اسلام مشوق و انگیزه او\nدر پیوستن به خیل عظیم انقلابیون بود که او را به خیل عظیم امت اسلامی در مبارزه\nهمگانی با ظلم و طاغوت می\u200cکشاند.\n\nدر سال ۶۳ فراز دیگری از زندگی\u200cاش را با ورود به دانشگاه آغاز کرد و با 
# ...

# %% [markdown]
# # سوال ۵

# %% [markdown]
# ###   الف) بین‌الملل

# %%
res =Query().start('بین‌الملل')
print_origin_new(res)
# Out:
# توضیحات مسؤول مسابقات لیگ یک درباره شایعه سکته ناظر بازی -- 1
#
# اعلام آخرین اقدامات تراکتور برای بازشدن پنجره/ احتمال استفاده از بازیکنان جدید برابر گل‌گهر -- 2
#
# گزارش تمرین پرسپولیس| روحیه شاد قبل از مصاف با الهلال/ پا به توپ شدن گل‌محمدی و باقری -- 3
#
# واکنش نصیرزاده به اظهارات مالک ماشین سازی: به جای فرافکنی به تعهداتتان عمل کنید -- 4
#
# باج بن سلمان به انگلیس و قطر/ پروژه فوتبالی آل سعود چگونه رقم خورد؟ -- 5
#
# پنجره نقل و انتقالات باشگاه فولاد خوزستان باز شد -- 6
#
# معاون بین‌الملل و  مدیر کمیته حرفه ای سازی باشگاه استقلال منصوب شدند -- 7
#
# باشگاه پرسپولیس خواستار ارسال تاییدیه AFC برای هتل محل اقامت -- 8
#
# تائید حضور تماشاگر در دیدار تیم ملی فوتبال مقابل کره جنوبی توسط وزیر ورزش -- 9
#
# نامه پرسپولیس به کنفدراسیون فوتبال آسیا برای اسکان شاگردان گل محمدی در ریاض -- 10
#
# واکنش عضو کمیسیون اقتصادی مجلس به گرانی لوازم خانگی داخلی/ تولیدکنندگان بدانند کسی به آنها چک سفید امضاء نداده است -- 11
#
# جهاد مسئولان، قوام‌بخش وحدت مردم خواهد بود -- 12
#
# ...

# %% [markdown]
# ###   ب) دانشگاه امیرکبیر

# %%
res =Query().start('دانشگاه امیرکبیر')
# Out:
# [7236, 1959, 2792, 2793, 2131, 1753, 7520, 2709, 5021, 5022]
# 1 -- برگزاری یادبودی برای محمدسرور رجایی
#
# 2 -- نامه ۸ بسیج دانشجویی دانشگاه‌های تهران به معاون اول رئیس جمهور
#
# 3 -- امروز محیط دانشگاه‌های ما عرصه دفاع مقدس است
#
# 4 -- باید برای ثبت نقش دانشگاهیان در دوران دفاع مقدس کار تحقیقاتی صورت گیرد
#
# 5 -- بزرگداشت شهدای مسجد قندوز در مقابل کنسولگری افغانستان/ آمریکا و آل سعود مقصران اصلی جنایت در افغانستان
#
# 6 -- نامه جمعی از اساتید و متخصصان/ آقای رئیس‌جمهور در گام دوم انقلاب به داد «مدیریت» در کشور برسید
#
# 7 -- اعطای گواهی درجه یک هنری به سعید بیابانکی
#
# 8 -- پیشرفت‌ صنایع هوایی ما قابل مقایسه با قبل از انقلاب نیست/ شب و روز صهیونیست‌ها در وحشت است
#
# 9 -- دفترچه راهنمای آزمون استخدامی دانشگاه‌ها برای بار چهارم اصلاح شد/تمدید مجدد مهلت ثبت‌نام
#
# 10 -- دفترچه راهنمای آزمون استخدامی دانشگاه‌ها برای بار چهارم اصلاح شد/تمدید مجدد مهلت ثبت‌نام
